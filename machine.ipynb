# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark=SparkSession.builder.appName('mach').getOrCreate()
from pyspark.ml.regression import LinearRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
wa=sqlContext.sql("SELECT * FROM ecommerce_customers_83b1c_csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
wa.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- email: string (nullable = true)
# -- address: string (nullable = true)
# -- avatar: string (nullable = true)
# -- avg sess: double (nullable = true)
# -- app time: double (nullable = true)
# -- web time: double (nullable = true)
# -- mem len: double (nullable = true)
# -- year amt: double (nullable = true)
#
# </div>

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
wa.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>
# [&apos;email&apos;,
#  &apos;address&apos;,
#  &apos;avatar&apos;,
#  &apos;avg sess&apos;,
#  &apos;app time&apos;,
#  &apos;web time&apos;,
#  &apos;mem len&apos;,
#  &apos;year amt&apos;]
# </div>

# %%
assembler=VectorAssembler(inputCols=['avg sess','app time','web time','mem len'],outputCol='features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output = assembler.transform(wa)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- email: string (nullable = true)
# -- address: string (nullable = true)
# -- avatar: string (nullable = true)
# -- avg sess: double (nullable = true)
# -- app time: double (nullable = true)
# -- web time: double (nullable = true)
# -- mem len: double (nullable = true)
# -- year amt: double (nullable = true)
# -- features: vector (nullable = true)
#
# </div>

# %%
output.select('app time').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#           app time|
# +------------------+
#               null|
#  12.65565114916675|
# 11.109460728682564|
# 11.330278057777512|
# 13.717513665142507|
# 12.795188551078114|
# 12.026925339755056|
# 11.366348309710526|
#  12.35195897300293|
# 13.386235275676436|
# 11.814128294972196|
# 13.338975447662113|
# 11.584782999535266|
# 10.961298400154098|
# 12.959226091609382|
# 13.148725692056516|
# 12.636606052000127|
# 11.733861690857394|
# 12.013194694014402|
#   14.7153875441565|
# +------------------+
# only showing top 20 rows
#
# </div>

# %%
wa.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+----------------+------------------+------------------+------------------+------------------+------------------+
#                email|             address|          avatar|          avg sess|          app time|          web time|           mem len|          year amt|
# +--------------------+--------------------+----------------+------------------+------------------+------------------+------------------+------------------+
#                 null|                null|            null|              null|              null|              null|              null|              null|
# ...
